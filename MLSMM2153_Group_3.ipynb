# %%
# %pip install pandas # pour manipuler des tableaux de données (dataframes)
# %pip install openpyxl # pour lire les fichiers Excel .xlsx
# %pip install requests # pour envoyer des requêtes HTTP (aller chercher une page web)
# %pip install beautifulsoup4 # pour lire une page web
# %pip install scikit-learn
# %pip install nltk # pour le traitement du langage naturel
# %pip install matplotlib seaborn
# %pip install wordcloud
# %pip install networkx

# %% [markdown]
# Navigation pour la collecte des données

# %%
from pathlib import Path # pour manipuler les chemins de fichiers
import pandas as pd # pour manipuler des tableaux de données (dataframes)
import requests # Importe la librairie pour envoyer des requêtes HTTP (aller chercher une page web)

# En-têtes HTTP : Se faire passer pour un vrai navigateur pour éviter certains blocages anti-bot
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}

# Chemin vers le fichier Excel
excel_path = Path("Organisations.xlsx")

# Vérifie si le fichier excel existe sinon le script s'arrête
if excel_path.exists():
    print("Excel trouvé :", excel_path.resolve())
else:
    print("Excel non trouvé :", excel_path.resolve())
    raise FileNotFoundError()

# Lire le fichier Excel et le mettre dans une variable df_excel sous forme de tableau pandas (un DataFrame).
df_excel = pd.read_excel(excel_path)
print()
print("Aperçu des données Excel :")
print(df_excel.head(5)) # Affiche les 5 premières lignes du tableau
print()

# Détection intelligente des colonnes

# Nettoyer les noms de colonnes forcant en string et enlevant les espaces
df_excel.columns = df_excel.columns.astype(str).str.strip()
print(df_excel.columns.tolist())

# Fonction pour trouver la colonne correspondant parmi des noms possibles sinon retourner la colonne par défaut (peut etre suprimée)
def trouver_colonne(noms_possibles, colonne_defaut):
    for nom_colonne in df_excel.columns:
        if nom_colonne.lower() in noms_possibles:
            return nom_colonne
    return df_excel.columns[colonne_defaut]

colone_noms = trouver_colonne({"name", "nom", "organisation", "organization"}, 0)
colone_url  = trouver_colonne({"url", "link", "website", "site", "web", "homepage"}, 1)
print()
print("Colonnes détectées :" + "\n Nom: " + colone_noms + "\n url: " + colone_url)

# Fonction pour nettoyer les URLs (peut être suprimée)
def nettoyer_url(url: str) -> str:
    # Enlève les espaces au début/fin
    if pd.isna(url):
        return ""
    url = url.strip()
    # Si vide ou "nan", on ignore
    if url == "" or url.lower() == "nan":
        return ""
    # Si l'URL n'a pas http:// ou https://, on l'ajoute
    if not url.lower().startswith(("http://", "https://")):
        url = "https://" + url
    return url

# Extraire les colonnes spécifiques en listes (peut être suprimée)
Noms = df_excel[colone_noms].tolist()
urls = df_excel[colone_url].tolist()

def read_html_url(url: str):
    # Essayer d'envoyer une requête GET au site web (télécharge le contenu de la page)
    try:
        response = requests.get(url, headers=headers, timeout=5, allow_redirects=True)
        if response.status_code != 200:
            return response.status_code, None
        # Optionnel c'est si Requests ne sait pas quel encodage utiliser, alors elle utilise l’encodage deviné automatiquement (peut être suprimée)
        if not response.encoding:
            response.encoding = response.apparent_encoding
        return response.status_code, response.text
    except requests.Timeout:
        return "Erreur Timeout", None
    except requests.ConnectionError:
        return "Erreur Connexion", None 
    except requests.HTTPError:
        return "Erreur HTTP", None
    except requests.TooManyRedirects:
        return "Trop de redirections", None
    except requests.URLRequired:
        return "URL invalide", None
    except requests.RequestException:
        return "Autre erreur", None

for nom, url in zip(Noms, urls):
    url = nettoyer_url(url)
    if not url:
        continue
    status_code, texte = read_html_url(url)
    print("\nNom :", nom)
    print("URL :", url)
    print("Statut de la requête :", status_code)
    # Affiche les 100 premiers caractères du contenu HTML
    if texte is None:
            print("Pas de contenu car erreur lors de la requête.")
            continue
    if len(texte) < 100:
        print("contenue faible :", texte)
    else:
        print("Contenu de la page (extrait) :", texte[:100])
# Out:
# Excel trouvé : C:\Users\krack\Desktop\Data collection\Organisations.xlsx
#
# Aperçu des données Excel :
#         Name                                    URL
# 0      Adobe      https://www.adobe.com/about-adobe
# 1     Google                   https://about.google
# 2  Microsoft  https://www.microsoft.com/en-us/about
# 3     Amazon   https://www.aboutamazon.com/about-us
# 4      Apple       https://www.apple.com/leadership
#
# ['Name', 'URL']
#
# Colonnes détectées :
#  Nom: Name
#  url: URL
#
# Nom : Adobe
# URL : https://www.adobe.com/about-adobe
# Statut de la requête : Erreur Timeout
# Pas de contenu car erreur lors de la requête.
#
# Nom : Google
# URL : https://about.google
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html>
# <html class="page" dir="ltr" lang="en-US" locale="en-US">
#   <head>
#     <meta charset
#
# Nom : Microsoft
# URL : https://www.microsoft.com/en-us/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
#
# <html lang="en-US" dir="ltr">
#   <head>
#
#
#
#
#
#
#
#
#
#
#
# Nom : Amazon
# URL : https://www.aboutamazon.com/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=dev
#
# Nom : Apple
# URL : https://www.apple.com/leadership
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
#
#
#
#
# 	<html xmlns="http://www.w3.org/1999/xhtml" xml:lang="en-US" lang="en-US" dir="l
#
# Nom : Spotify
# URL : https://newsroom.spotify.com/company-info
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!doctype html>
#
# <html class="no-js" lang="en-US">
#
# <head>
#     <meta charset="utf-8">
#
#     <!-- For
#
# Nom : Netflix
# URL : https://about.netflix.com/en
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html lang="en" dir="ltr"><head><meta property="og:type" content="website"/><meta pro
#
# Nom : IBM
# URL : https://www.ibm.com/about
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE HTML>
#
# <html lang="en">
# <head>
#
#
#
#
#
#
#
#
#
#
#
# Nom : Siemens
# URL : https://www.siemens.com/global/en/company/about.html
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang='en' dir='ltr'>
#
#   <head>
#     <meta charset='utf-8' />
#     <link rel="sty
#
# Nom : Tesla
# URL : https://www.tesla.com/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Harvard University
# URL : https://www.harvard.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE html>
# <html lang="en-US">
#
# <head>
#
# 		<meta charset="utf-8">
# 	<meta name="author" content
#
# Nom : Massachusetts Institute of Technology
# URL : https://www.mit.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" class="no-js theme--nimbus-3000">
#   <head>
#     <meta charset="utf-8"
#
# Nom : Stanford University
# URL : https://www.stanford.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en-US" prefix="og: http://ogp.me/ns# fb: http://ogp.me/ns/fb#" class="no
#
# Nom : University of Oxford
# URL : https://www.ox.ac.uk/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html>
# <html lang="en" dir="ltr" class="no-js">
# <head>
#   <meta http-equiv="X-UA-Compatible"
#
# Nom : University of Cambridge
# URL : https://www.cam.ac.uk/about-the-university
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Yale University
# URL : https://www.yale.edu/about-yale
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html class="no-js" xml:lang="en" lang="en" dir="ltr">
#   <head>
#     <meta content="I
#
# Nom : Princeton University
# URL : https://www.princeton.edu/about
# Statut de la requête : Erreur Connexion
# Pas de contenu car erreur lors de la requête.
#
# Nom : Columbia University
# URL : https://www.columbia.edu/content/about-columbia
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : University of Chicago
# URL : https://www.uchicago.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html><html lang="en"><head><title data-react-helmet="true">Who We Are | University of Chic
#
# Nom : University of Toronto
# URL : https://www.utoronto.ca/about-u-of-t
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <meta charse
#
# Nom : Amnesty International
# URL : https://www.amnesty.org/en/about-us
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Greenpeace
# URL : https://www.greenpeace.org/international/about
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE html>
# <html lang="en" data-base="https://www.greenpeace.org/international/">
# <head>
#     <
#
# Nom : World Wide Fund for Nature
# URL : https://www.worldwildlife.org/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Oxfam
# URL : https://www.oxfam.org/en/about-us
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : Doctors Without Borders
# URL : https://www.doctorswithoutborders.org/who-we-are
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <meta charse
#
# Nom : Save the Children
# URL : https://www.savethechildren.net/about-us
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Human Rights Watch
# URL : https://www.hrw.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <meta charse
#
# Nom : CARE International
# URL : https://www.care-international.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
# <head>
# <title>About us |
#
# Nom : Plan International
# URL : https://plan-international.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
#
# <html lang="en-GB">
#
# <head>
# 	<meta charset="UTF-8">
# 	<meta name="viewport" content=
#
# Nom : Transparency International
# URL : https://www.transparency.org/en/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : United Nations
# URL : https://www.un.org/en/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE html>
# <html dir="ltr" lang="en"><head profile="http://www.w3.org/1999/xhtml/vocab">
#
#
# Nom : World Health Organization
# URL : https://www.who.int/about
# Statut de la requête : 200
# Contenu de la page (extrait) :  <!DOCTYPE html> <html lang="en"> <head> <!-- head to scrape:on --> <meta http-equiv="X-UA-Compatibl
#
# Nom : UNESCO
# URL : https://www.unesco.org/en/about-us
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : European Commission
# URL : https://commission.europa.eu/about-european-commission_en
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <meta charse
#
# Nom : World Bank
# URL : https://www.worldbank.org/en/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html>
#   <head>
#     <title>Who We Are</title>
#     <link rel="canonical" href="https:
#
# Nom : International Monetary Fund
# URL : https://www.imf.org/en/About
# Statut de la requête : Erreur Timeout
# Pas de contenu car erreur lors de la requête.
#
# Nom : Organisation for Economic Co-operation and Development
# URL : https://www.oecd.org/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : North Atlantic Treaty Organization
# URL : https://www.nato.int/cps/en/natohq/who_we_are.htm
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : UNICEF
# URL : https://www.unicef.org/about-us
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : International Labour Organization
# URL : https://www.ilo.org/global/about-the-ilo/lang--en/index.htm
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
# <head>
#               <lin
#
# Nom : The Nature Conservancy
# URL : https://www.nature.org/en-us/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE html>
# <html lang="en-US" dir="ltr">
#
#
#
#
# <head>
#
#
#     <meta charset="utf-8"/>
#
#
# Nom : Conservation International
# URL : https://www.conservation.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html lang="en" class="fontproximanova_fe98dcc0-module__hZcYSW__variable fontproximan
#
# Nom : Environmental Defense Fund
# URL : https://www.edf.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head data-admin="false
#
# Nom : Friends of the Earth
# URL : https://friendsoftheearth.uk/about
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE html>
# <html  lang="en-gb" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <meta c
#
# Nom : Sierra Club
# URL : https://www.sierraclub.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html  lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <!-- begin
#
# Nom : Rainforest Alliance
# URL : https://www.rainforest-alliance.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en-US">
# <head >
# <meta charset="UTF-8" />
# <script type="text/javascript">
#
# Nom : Global Footprint Network
# URL : https://www.footprintnetwork.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html>
# <html lang="en-US" class="no-js">
# <head>
#     <script>(function (H) {
#             H.c
#
# Nom : Climate Action Network
# URL : https://climatenetwork.org/about
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : Earthwatch Institute
# URL : https://earthwatch.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <meta charse
#
# Nom : World Resources Institute
# URL : https://www.wri.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#         <script>
#
# Nom : International Committee of the Red Cross
# URL : https://www.icrc.org/en/who-we-are
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : Doctors of the World
# URL : https://doctorsoftheworld.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html>
# <html lang="en-US" prefix="og: https://ogp.me/ns#">
#
# <head>
# 	<link rel="preload" hre
#
# Nom : International Rescue Committee
# URL : https://www.rescue.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <meta charse
#
# Nom : Action Against Hunger
# URL : https://www.actionagainsthunger.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en">
#   <head>
#     <meta
#       http-equiv="Content-Security-Policy"
#
#
# Nom : Médecins du Monde
# URL : https://www.medecinsdumonde.org/en/about-us
# Statut de la requête : 200
# contenue faible : deprecated
#
# Nom : PATH
# URL : https://www.path.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE
#
# Nom : Gavi, the Vaccine Alliance
# URL : https://www.gavi.org/our-alliance/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : UNAIDS
# URL : https://www.unaids.org/en/aboutunaids
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="">
#   <head profile="">
#
#     <meta id="viewport" name="viewp
#
# Nom : World Food Programme
# URL : https://www.wfp.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
# <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
# <head>
#
#         <!-
#
# Nom : Save the Children Health Programs
# URL : https://www.savethechildren.org/us/about-us
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Intel
# URL : https://www.intel.com/content/www/us/en/company-overview/company-overview.html
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Cisco
# URL : https://www.cisco.com/c/en/us/about.html
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE HTML>
#
# <html lang="en-US" dir="ltr">
#     <head>
#     <meta charset="UTF-8"/>
#     <meta nam
#
# Nom : Oracle
# URL : https://www.oracle.com/corporate/
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en-US" class="no-js"><!-- start : Framework/Redwood2 -->
# <!-- start : oc
#
# Nom : SAP
# URL : https://www.sap.com/about.html
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Dell Technologies
# URL : https://www.dell.com/en-us/dt/corporate/about-dell.htm
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : HP (Hewlett-Packard)
# URL : https://www.hp.com/us-en/hp-information/about-hp.html
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html class=" " xmlns="http://www.w3.org/1999/xhtml" lang="en-us" xml:lang="en-us" d
#
# Nom : NVIDIA
# URL : https://www.nvidia.com/en-us/about-nvidia/
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE HTML>
#
# <!--[if lt IE 7]><html class="html-page no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <
#
# Nom : PayPal
# URL : https://www.paypal.com/us/webapps/mpp/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Visa
# URL : https://www.visa.com/about-visa.html
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html>
#
#
#     <html class="classic" prefix="og: http://ogp.me/ns#" lang="nl" dir="ltr">
#
#
# Nom : Mastercard
# URL : https://www.mastercard.com/about-mastercard.html
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : University of California, Los Angeles
# URL : https://www.ucla.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html>
#
# <html class="no-js" lang="en">
#
# <head>
#   <meta charset="UTF-8">
#   <meta http-equiv=
#
# Nom : University of California, Berkeley
# URL : https://www.berkeley.edu/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Cornell University
# URL : https://www.cornell.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!
#
# Nom : Brown University
# URL : https://www.brown.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#" class="no-js" itemscope=""
#
# Nom : Duke University
# URL : https://www.duke.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en-US">
# <head><meta charset="UTF-8">
#
# 	<meta name="viewport" content="w
#
# Nom : Johns Hopkins University
# URL : https://www.jhu.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html>
#
# <html class="no-js" lang="en">
#   <head>
#     <script>
#     dataLayer = [];
#     </scri
#
# Nom : New York University
# URL : https://www.nyu.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
#
# <?xml version="1.0" encoding="UTF-8"?>
# <!DOCTYPE html>
# <html xml:lang="en" lang="en">
#     <head>
#
#
# Nom : University of Pennsylvania
# URL : https://www.upenn.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html class="no-js" lang="en">
#
#   <head>
#     <script>
#       document.documentElement
#
# Nom : University of Texas at Austin
# URL : https://www.utexas.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <meta charse
#
# Nom : University of Southern California
# URL : https://www.usc.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!doctype html>
# <!--[if lt IE 9]><html class="no-js no-svg ie lt-ie9 lt-ie8 lt-ie7" lang="en-US"> <
#
# Nom : Habitat for Humanity
# URL : https://www.habitat.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
# <!DOCTYPE html>
# <html lang="en-003" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#
#
# Nom : Oxfam America
# URL : https://www.oxfamamerica.org/explore/about-us/
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : International Federation of Red Cross and Red Crescent Societies
# URL : https://www.ifrc.org/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Mercy Corps
# URL : https://www.mercycorps.org/about
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : HelpAge International
# URL : https://www.helpage.org/about-us/
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
#
#
#
#
#
#
#
#
#
#
# <!doctype html>
# 	<!--[if IE]> <html lang="en" class="no-js ie"> <![endif]-->
# 	<!--[if !I
#
# Nom : WaterAid
# URL : https://www.wateraid.org/us/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Global Citizen
# URL : https://www.globalcitizen.org/en/about/
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><!--[if lt IE 7]><html class="no-js lt-ie9 lt-ie8 lt-ie7"><![endif]--><!--[if IE 7]><
#
# Nom : CARE USA
# URL : https://www.care.org/about-us/
# Statut de la requête : 200
# Contenu de la page (extrait) : 	<!DOCTYPE html>
# <!--[if lte IE 8 ]>
# <html lang="en" class="no-js oldie">
# <![endif]-->
# <!--[if IE 9
#
# Nom : IRC WASH (International Rescue Committee – WASH)
# URL : https://www.ircwash.org/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Concern Worldwide
# URL : https://www.concern.net/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html lang="en"><head><script nonce="tgguNyS/dg/RlxGJ3nU39w==">(function() {
#
#
# Nom : University of California, Los Angeles
# URL : https://www.unhcr.org/about-us.html
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : University of California, Berkeley
# URL : https://www.iom.int/about-iom
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Cornell University
# URL : https://www.unido.org/who-we-are
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Brown University
# URL : https://www.ifad.org/en/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Duke University
# URL : https://www.unicef.org/innovation/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Johns Hopkins University
# URL : https://www.fao.org/about/en
# Statut de la requête : 200
# Contenu de la page (extrait) :  <!DOCTYPE html> <html lang="en" > <head> <meta charset="utf-8" /> <meta name="viewport" content="wi
#
# Nom : New York University
# URL : https://www.undp.org/about-us
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : University of Pennsylvania
# URL : https://www.unwomen.org/en/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/
#
# Nom : University of Texas at Austin
# URL : https://www.wto.org/english/thewto_e/whatis_e/wto_dg_stat_e.htm
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta http-equiv="X-UA-Compatible" content="IE=Edge">
# <s
#
# Nom : University of Southern California
# URL : https://www.wipo.int/about-wipo/en/
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 			<!DOCTYPE html>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nom : Habitat for Humanity
# URL : https://www.greenpeaceusa.org/about/
# Statut de la requête : Erreur Connexion
# Pas de contenu car erreur lors de la requête.
#
# Nom : Oxfam America
# URL : https://www.ucsusa.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <title>About
#
# Nom : International Federation of Red Cross and Red Crescent Societies
# URL : https://www.worldwildlife.org/about/mission-and-values
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Mercy Corps
# URL : https://www.nrdc.org/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : HelpAge International
# URL : https://www.ewg.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#       <!-- Fundr
#
# Nom : WaterAid
# URL : https://www.climatecentral.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=dev
#
# Nom : Global Citizen
# URL : https://www.cdp.net/en/info/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html lang="en" class="__className_15a04f"><head><meta charSet="utf-8"/><meta name="v
#
# Nom : CARE USA
# URL : https://www.iucn.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <meta charse
#
# Nom : IRC WASH (International Rescue Committee – WASH)
# URL : https://www.wwf.org.uk/about-us
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : Concern Worldwide
# URL : https://www.climateactiontracker.org/about/
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en">
#
# <head>
#     <meta charset="utf-8"/>
#     <meta http-equiv="X-UA-Comp
#
# Nom : Habitat for Humanity
# URL : https://www.cdcfoundation.org/about
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : Oxfam America
# URL : https://www.alima.ngo/en/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html>
# <html lang="en-GB" prefix="og: https://ogp.me/ns#">
# <head>
# 	<meta charset="UTF-8">
#
#
# Nom : International Federation of Red Cross and Red Crescent Societies
# URL : https://www.fhi360.org/about-us
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Mercy Corps
# URL : https://www.psi.org/about/
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : HelpAge International
# URL : https://www.ghsindex.org/about/
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
# 			<!DOCTYPE html>
# <!--[if lt IE 7]>      <html <?php language_attributes(); ?> class="ie6 lt-ie9
#
# Nom : WaterAid
# URL : https://www.malariaconsortium.org/about/
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Global Citizen
# URL : https://www.tballiance.org/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : CARE USA
# URL : https://www.unfpa.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html  lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#
#         <scrip
#
# Nom : IRC WASH (International Rescue Committee – WASH)
# URL : https://www.amref.org/about-us/
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en-GB">
# <head>
# 	<meta charset="UTF-8">
# 	<meta name="viewport" content="w
#
# Nom : Concern Worldwide
# URL : https://www.healthright.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang=en-US> <head><meta http-equiv=Content-Type content="text/html;charset=UTF
#
# Nom : World Economic Forum
# URL : https://www.weforum.org/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : International Organization for Migration
# URL : https://www.iom.int/about-iom
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : United Nations Development Programme
# URL : https://www.undp.org/about-us
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Food and Agriculture Organization of the United Nations
# URL : https://www.fao.org/about/en
# Statut de la requête : 200
# Contenu de la page (extrait) :  <!DOCTYPE html> <html lang="en" > <head> <meta charset="utf-8" /> <meta name="viewport" content="wi
#
# Nom : World Trade Organization
# URL : https://www.wto.org/english/thewto_e/whatis_e/wto_dg_stat_e.htm
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta http-equiv="X-UA-Compatible" content="IE=Edge">
# <s
#
# Nom : International Fund for Agricultural Development
# URL : https://www.ifad.org/en/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : International Renewable Energy Agency
# URL : https://www.irena.org/About
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
#
# <!doctype html>
# <html lang="en">
# <head>
#
#
#
#
# <meta charset="utf-8">
# <meta name="vie
#
# Nom : UN Environment Programme
# URL : https://www.unep.org/about-un-environment
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : UN Women
# URL : https://www.unwomen.org/en/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="content: http://purl.org/rss/1.0/modules/content/
#
# Nom : International Telecommunication Union
# URL : https://www.itu.int/en/about/Pages/default.aspx
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
# <!-- ITU template starts : language INdependent -->
#
# <!-- ITU template ends -->
#
# <!DOCTYPE H
#
# Nom : Bill & Melinda Gates Foundation
# URL : https://www.gatesfoundation.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE html>
# <html lang="en" dir="ltr">
# <head>
#
#
#
#     <title>About</title>
#
#     <me
#
# Nom : Rockefeller Foundation
# URL : https://www.rockefellerfoundation.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html> <!--[if lt IE 9]><html class="no-js no-svg ie lt-ie9 lt-ie8 lt-ie7" lang="en-US"> <!
#
# Nom : Ford Foundation
# URL : https://www.fordfoundation.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en-US">
# <head>
# 	<meta charset="UTF-8" />
# 	<!-- OptanonConsentNoticeStart
#
# Nom : Wellcome Trust
# URL : https://wellcome.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html class="tw-box-border tw-scroll-smooth tw-antialiased motion-reduce:tw-scroll-au
#
# Nom : Open Society Foundations
# URL : https://www.opensocietyfoundations.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html dir="ltr" lang="en" class="no-js page-who-we-are" data-active-nav="who-we-are"
#
# Nom : Carnegie Endowment for International Peace
# URL : https://carnegieendowment.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html  class="notranslate" translate="no" lang="en" dir="ltr" data-capo=""><head><met
#
# Nom : Skoll Foundation
# URL : https://skoll.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
#
#
#
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7"> <![en
#
# Nom : Clinton Health Access Initiative
# URL : https://www.clintonhealthaccess.org/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Mo Ibrahim Foundation
# URL : https://mo.ibrahim.foundation/about
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : Bloomberg Philanthropies
# URL : https://www.bloomberg.org/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : World Wildlife Fund UK
# URL : https://www.wwf.org.uk/about-us
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : Natural Resources Defense Council
# URL : https://www.nrdc.org/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Union of Concerned Scientists
# URL : https://www.ucsusa.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <title>About
#
# Nom : Environmental Working Group
# URL : https://www.ewg.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#       <!-- Fundr
#
# Nom : Climate Central
# URL : https://www.climatecentral.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta name="viewport" content="width=dev
#
# Nom : International Union for Conservation of Nature
# URL : https://www.iucn.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <meta charse
#
# Nom : Conservation International Europe
# URL : https://www.conservation.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html lang="en" class="fontproximanova_fe98dcc0-module__hZcYSW__variable fontproximan
#
# Nom : Global Environment Facility
# URL : https://www.thegef.org/about
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : World Conservation Monitoring Centre
# URL : https://www.unep-wcmc.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html>
# <html data-n-head-ssr lang="en" data-n-head="%7B%22lang%22:%7B%22ssr%22:%22en%22%7D%
#
# Nom : Ocean Conservancy
# URL : https://oceanconservancy.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en-US">
# <head>
# 	<meta charset="UTF-8" /><script type="text/javascript">(
#
# Nom : London School of Economics and Political Science
# URL : https://www.lse.ac.uk/about-lse
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html><html lang="en" dir="ltr"><head><meta charset="utf-8"/><title data-react-helmet="true
#
# Nom : University College London
# URL : https://www.ucl.ac.uk/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#">
#   <head>
#     <meta charse
#
# Nom : King’s College London
# URL : https://www.kcl.ac.uk/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html><html itemscope itemtype="http://schema.org/" lang="en" dir="ltr"><head><meta data-re
#
# Nom : ETH Zurich
# URL : https://ethz.ch/en/the-eth-zurich.html
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
#
# <html lang="en">
#     <head>
#     <meta charset="utf-8" >
#     <link rel="canonical"
#
# Nom : University of Amsterdam
# URL : https://www.uva.nl/en/about-the-uva/about-the-university.html
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
#
#
#
#
# <!doctype html>
# <html class="no-js" lang="en">
# <head>
#     <meta charset="utf-8"/>
#
#     <title>
#
# Nom : University of Copenhagen
# URL : https://www.ku.dk/english/about
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : University of Melbourne
# URL : https://www.unimelb.edu.au/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Australian National University
# URL : https://www.anu.edu.au/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html lang="en" dir="ltr" prefix="og: https://ogp.me/ns#"><head><meta charset="utf-8"
#
# Nom : University of Tokyo
# URL : https://www.u-tokyo.ac.jp/en/about
# Statut de la requête : Erreur Connexion
# Pas de contenu car erreur lors de la requête.
#
# Nom : Accenture
# URL : https://www.accenture.com/us-en/about/company-index
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE HTML>
# <html lang="en-US">
#     <head>
#     <meta charset="UTF-8"/>
#
#
#         <title
#
# Nom : Deloitte
# URL : https://www2.deloitte.com/global/en/pages/about-deloitte/articles/about-deloitte.html
# Statut de la requête : 200
# Contenu de la page (extrait) :
#
#
#
#
#
#
#
#
# <!DOCTYPE HTML>
#
#         <html lang="en" prefix="og: https://ogp.me
#
# Nom : PwC
# URL : https://www.pwc.com/gx/en/about.html
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE HTML>
# <html lang="en">
#     <head>
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Nom : EY
# URL : https://www.ey.com/en_gl/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE html>
# <html lang="en">
#   <head>
#   <meta charset="UTF-8"/>
#
#   <title>About us | EY - Glo
#
# Nom : McKinsey & Company
# URL : https://www.mckinsey.com/about-us
# Statut de la requête : Erreur Timeout
# Pas de contenu car erreur lors de la requête.
#
# Nom : Boston Consulting Group
# URL : https://www.bcg.com/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Capgemini
# URL : https://www.capgemini.com/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html>
# <html lang="en-US">
# <head>
# 	<meta charset="UTF-8" />
# 	<meta name="viewport" content=
#
# Nom : Infosys
# URL : https://www.infosys.com/about.html
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Tata Consultancy Services
# URL : https://www.tcs.com/who-we-are
# Statut de la requête : 200
# Contenu de la page (extrait) :
# <!DOCTYPE HTML>
# <html lang="en">
#     <head>
#   <link rel="dns-prefetch" href="https://maps.googleapi
#
# Nom : IBM Research
# URL : https://research.ibm.com/about
# Statut de la requête : 200
# Contenu de la page (extrait) : <!DOCTYPE html><html lang="en-US"><head><meta charSet="utf-8" data-next-head=""/><title data-next-he
#
# Nom : Airbnb
# URL : https://about.airbnb.com
# Statut de la requête : Erreur Connexion
# Pas de contenu car erreur lors de la requête.
#
# Nom : Uber
# URL : https://www.uber.com/about
# Statut de la requête : 406
# Pas de contenu car erreur lors de la requête.
#
# Nom : Lyft
# URL : https://www.lyft.com/about
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : Booking Holdings
# URL : https://www.bookingholdings.com/about
# Statut de la requête : 200
# Contenu de la page (extrait) :  <!DOCTYPE html>
# <!--[if IE 7]>
# <html class="ie ie7" dir="ltr" lang="en-US" prefix="og: https://ogp.
#
# Nom : Expedia Group
# URL : https://www.expediagroup.com/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Tripadvisor
# URL : https://www.tripadvisor.com/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Salesforce
# URL : https://www.salesforce.com/company
# Statut de la requête : 200
# Contenu de la page (extrait) : <!doctype html><html lang="en"><head><meta charset="UTF-8" /><meta name="viewport" content="width=de
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1430, in HTTPConnection.getresponse(self)
#    1429 try:
# -> 1430     response.begin()
#    1431 except ConnectionError:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\socket.py:719, in SocketIO.readinto(self, b)
#     718 try:
# --> 719     return self._sock.recv_into(b)
#     720 except timeout:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1304, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1301         raise ValueError(
#    1302           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1303           self.__class__)
# -> 1304     return self.read(nbytes, buffer)
#    1305 else:
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\ssl.py:1138, in SSLSocket.read(self, len, buffer)
#    1137 if buffer is not None:
# -> 1138     return self._sslobj.read(len, buffer)
#    1139 else:
#
# TimeoutError: The read operation timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 88
#      86 if not url:
#      87     continue
# ---> 88 status_code, texte = read_html_url(url)
#      89 print("\nNom :", nom)
#      90 print("URL :", url)
#
# Cell In[19], line 64, in read_html_url(url)
#      61 def read_html_url(url: str):
#      62     # Essayer d'envoyer une requête GET au site web (télécharge le contenu de la page)
#      63     try:
# ---> 64         response = requests.get(url, headers=headers, timeout=5, allow_redirects=True)
#      65         if response.status_code != 200:
#      66             return response.status_code, None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)     70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\requests\adapters.py:644, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     641     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     643 try:
# --> 644     resp = conn.urlopen(
#     645         method=request.method,
#     646         url=url,
#     647         body=request.body,
#     648         headers=request.headers,
#     649         redirect=False,
#     650         assert_same_host=False,
#     651         preload_content=False,
#     652         decode_content=False,
#     653         retries=self.max_retries,
#     654         timeout=timeout,
#     655         chunked=chunked,
#     656     )
#     658 except (ProtocolError, OSError) as err:
#     659     raise ConnectionError(err, request=request)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\urllib3\connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     784 response_conn = conn if not release_conn else None
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#     803 clean_exit = True
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\urllib3\connectionpool.py:534, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     532 # Receive the response from the server
#     533 try:
# --> 534     response = conn.getresponse()
#     535 except (BaseSSLError, OSError) as e:
#     536     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\urllib3\connection.py:571, in HTTPConnection.getresponse(self)
#     568 _shutdown = getattr(self.sock, "shutdown", None)
#     570 # Get the response from http.client.HTTPConnection
# --> 571 httplib_response = super().getresponse()
#     573 try:
#     574     assert_header_parsing(httplib_response.msg)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:1446, in HTTPConnection.getresponse(self)
#    1444     return response
#    1445 except:
# -> 1446     response.close()
#    1447     raise
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.13_3.13.2544.0_x64__qbz5n2kfra8p0\Lib\http\client.py:430, in HTTPResponse.close(self)
#     427     self.fp = None
#     428     fp.close()
# --> 430 def close(self):
#     431     try:
#     432         super().close() # set "closed" flag
#
# KeyboardInterrupt:

# %% [markdown]
# Extraction du contenu HTML

# %%
import bs4    # Outil pour lire une page web
def make_soup(content: str):
    texte = bs4.BeautifulSoup(content, "html.parser") # Transforme le HTML en structure lisible par Python
    return texte

# %%
import re # gére les expressions régulières qui permettent de manipuler du texte (regex)
def extract_texte(texte):
    for tag in texte(["script", "style", "noscript"]):
        tag.decompose()

    # priorité au contenu dans <main> si présent (souvent beaucoup plus propre)
    main = texte.find("main")
    if main:
        text = main.get_text(separator=" ")
    else:
        text = texte.get_text(separator=" ")

    text = re.sub(r"\s+", " ", text).strip()
    return text

# %% [markdown]
# Stockage des données (CSV et JSON)

# %%
results = []
corpus = {}
Doublons = set()
for nom, url in zip(Noms, urls):
    url = nettoyer_url(url)
    if not url:
        continue

    nom = str(nom).strip()
    if not nom:
        continue

    # filtre doublons (on garde le 1er)
    if nom in Doublons:
        continue
    Doublons.add(nom)

    status_code, texte = read_html_url(url)

    print("\nNom :", nom)
    print("URL :", url)
    print("Statut de la requête :", status_code)
    # Affiche les 100 premiers caractères du contenu HTML
    if texte is None:
            print("Pas de contenu car erreur lors de la requête.")
            continue
    texte = make_soup(texte)
    texte = extract_texte(texte)
    if len(texte) < 50:
        print("contenue tres faible et insufisant :", texte)
        continue
    if len(texte) < 100:
        print("contenue faible :", texte)
    else:
        print("Contenu de la page (extrait) :", texte[:100])

    # dictionnaire[cle] = valeur
    corpus[nom] = texte
    texte_originale = corpus[nom]

    results.append({
        "name": nom,
        "url": url,
        "http_status": status_code,
        "text": texte,
        "text_length": len(texte)
    })

# 5 Export
df_excel_out = pd.DataFrame(results)
df_excel_out.to_csv("about_texts.csv", index=False, encoding="utf-8")
df_excel_out.to_json("about_texts.json", orient="records", force_ascii=False, indent=2)
print("\nDonnées exportées vers about_texts.csv et about_texts.json")
# Out:
# Nom : Adobe
# URL : https://www.adobe.com/about-adobe
# Statut de la requête : Erreur Timeout
# Pas de contenu car erreur lors de la requête.
#
# Nom : Google
# URL : https://about.google
# Statut de la requête : 200
# Contenu de la page (extrait) : Gemini 3 Flash: Bring any idea to life faster Our latest model with frontier intelligence built for
#
# Nom : Microsoft
# URL : https://www.microsoft.com/en-us/about
# Statut de la requête : 200
# Contenu de la page (extrait) : We empower the world Microsoft’s mission is to empower every person and every organization on the pl
#
# Nom : Amazon
# URL : https://www.aboutamazon.com/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : About Us | About Amazon News Stores and Shopping AWS Devices Entertainment Artificial Intelligence W
#
# Nom : Apple
# URL : https://www.apple.com/leadership
# Statut de la requête : 200
# Contenu de la page (extrait) : Executive Profiles Tim Cook CEO Katherine Adams Senior Vice President and General Counsel Eddy Cue S
#
# Nom : Spotify
# URL : https://newsroom.spotify.com/company-info
# Statut de la requête : 200
# Contenu de la page (extrait) : About Spotify About Spotify Since its launch in 2008, Spotify has revolutionised music listening. Ou
#
# Nom : Netflix
# URL : https://about.netflix.com/en
# Statut de la requête : 200
# Contenu de la page (extrait) : We are here to entertain the world, one fan at a time. Thrilling everyone again and again. Whatever
#
# Nom : IBM
# URL : https://www.ibm.com/about
# Statut de la requête : 200
# Contenu de la page (extrait) : About | IBM Home About About IBM Creators, partners and clients putting technology to work in the re
#
# Nom : Siemens
# URL : https://www.siemens.com/global/en/company/about.html
# Statut de la requête : 200
# Contenu de la page (extrait) : About Our technology accelerates customer transformations with industrial AI, boosting efficiency in
#
# Nom : Tesla
# URL : https://www.tesla.com/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Harvard University
# URL : https://www.harvard.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : About Harvard Those who join our community—to learn, research, teach, work, and grow—join nearly fou
#
# Nom : Massachusetts Institute of Technology
# URL : https://www.mit.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : Home About MIT About MIT The MIT community is driven by a shared purpose: to make a better world thr
#
# Nom : Stanford University
# URL : https://www.stanford.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : Main Content Who We Are From its founding in California in the late 19th century until today, Stanfo
#
# Nom : University of Oxford
# URL : https://www.ox.ac.uk/about
# Statut de la requête : 200
# Contenu de la page (extrait) : About the University of Oxford | University of Oxford Skip to main content Home Home Admissions Unde
#
# Nom : University of Cambridge
# URL : https://www.cam.ac.uk/about-the-university
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Yale University
# URL : https://www.yale.edu/about-yale
# Statut de la requête : 200
# Contenu de la page (extrait) : Explore our campus Old Campus and Harkness Tower Yale’s iconic Old Campus is where the university ce
#
# Nom : Princeton University
# URL : https://www.princeton.edu/about
# Statut de la requête : Erreur Connexion
# Pas de contenu car erreur lors de la requête.
#
# Nom : Columbia University
# URL : https://www.columbia.edu/content/about-columbia
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : University of Chicago
# URL : https://www.uchicago.edu/about
# Statut de la requête : 200
# Contenu de la page (extrait) : Who we are Driven to discover For more than 125 years, the University of Chicago has forged its own
#
# Nom : University of Toronto
# URL : https://www.utoronto.ca/about-u-of-t
# Statut de la requête : 200
# Contenu de la page (extrait) : About U of T Founded in 1827, the University of Toronto is Canada’s top university with a long histo
#
# Nom : Amnesty International
# URL : https://www.amnesty.org/en/about-us
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Greenpeace
# URL : https://www.greenpeace.org/international/about
# Statut de la requête : 200
# Contenu de la page (extrait) : A green and peaceful future is our quest Greenpeace exists because this fragile earth deserves a voi
#
# Nom : World Wide Fund for Nature
# URL : https://www.worldwildlife.org/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Oxfam
# URL : https://www.oxfam.org/en/about-us
# Statut de la requête : 404
# Pas de contenu car erreur lors de la requête.
#
# Nom : Doctors Without Borders
# URL : https://www.doctorswithoutborders.org/who-we-are
# Statut de la requête : 200
# contenue tres faible et insufisant :
#
# Nom : Save the Children
# URL : https://www.savethechildren.net/about-us
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : Human Rights Watch
# URL : https://www.hrw.org/about
# Statut de la requête : 200
# Contenu de la page (extrait) : Would you like to read this page in another language? Yes No, don't ask again ✕ Close Available In E
#
# Nom : CARE International
# URL : https://www.care-international.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : About us Founded in 1945 with the creation of the CARE Package®, we are a leading humanitarian organ
#
# Nom : Plan International
# URL : https://plan-international.org/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : About Plan International We are Plan International; we work with children and girls in over 80 count
#
# Nom : Transparency International
# URL : https://www.transparency.org/en/about
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : United Nations
# URL : https://www.un.org/en/about-us
# Statut de la requête : 200
# Contenu de la page (extrait) : About Us | United Nations Skip to main content Toggle navigation Welcome to the United Nations العرب
#
# Nom : World Health Organization
# URL : https://www.who.int/about
# Statut de la requête : 200
# Contenu de la page (extrait) : About WHO Skip to main content Global Regions WHO Regional websites Africa Americas South-East Asia
#
# Nom : UNESCO
# URL : https://www.unesco.org/en/about-us
# Statut de la requête : 403
# Pas de contenu car erreur lors de la requête.
#
# Nom : European Commission
# URL : https://commission.europa.eu/about-european-commission_en
# Statut de la requête : 200
# Contenu de la page (extrait) : Role of the European Commission The European Commission is the executive body of the European Union.
#
# Nom : World Bank
# URL : https://www.worldbank.org/en/about
# Statut de la requête : 200
# Contenu de la page (extrait) : style default Who We Are h1 false heading-top-xxlarge heading-bottom-regular We exist to create a wo

# %% [markdown]
# Informations : Nombre d'URLs, nombre de documents et corpus

# %%
df_clean = df_excel_out
print(len(urls))
print(len(df_clean))
print(len(corpus))

df_clean = df_clean.reset_index(drop=True)

print("Nb documents:", len(df_clean))
print(df_clean.head(8)[["name", "url", "text_length"]])
print('Corpus entier '+ str(corpus))

# %% [markdown]
# Nettoyer et Tokeniser

# %%
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

nltk.download("stopwords")
nltk.download("punkt")
nltk.download("wordnet")
nltk.download("omw-1.4")

stop_words = list(set(stopwords.words('english'))) + ["'s"]
stem = nltk.stem.SnowballStemmer("english")
lemmatizer = WordNetLemmatizer()

def nettoyer_texte(texte: str) -> str:
    texte = texte.lower()
    texte = re.sub(r"https?://\S+", " ", texte) # enlever les URLs
    texte = re.sub(r"www\.\S+", " ", texte) # enlever les URLs
    texte = re.sub(r"\d+", " ", texte) # enlever les chiffres
    texte = re.sub(r"[^a-z\s]", " ", texte) # remplacer tout ce qui n’est pas lettre ou espace par un espace
    texte = re.sub(r"\s+", " ", texte).strip() # réduire les espaces
    return texte

def tokenizer_stem(texte: str):
    tokens = word_tokenize(texte)
    tokens = [token for token in tokens if token not in stop_words and len(token) > 2]
    tokens = [token for token in tokens if token.isalpha()]
    tokens = [stem.stem(token) for token in tokens]
    return tokens

def tokenizer_lemma(texte: str):
    tokens = word_tokenize(texte)
    tokens = [token for token in tokens if token not in stop_words and len(token) > 2]
    tokens = [token for token in tokens if token.isalpha()]
    tokens = [lemmatizer.lemmatize(token) for token in tokens]
    return tokens

# %% [markdown]
# C'est deux autres manières de traiter une liste de documents (nettoyer → tokeniser → stocker/afficher)

# %%
df_nettoyer = df_clean["text"].apply(nettoyer_texte)
df_tokenizer_stem = df_nettoyer.apply(tokenizer_stem)
df_tokenizer_lemma = df_nettoyer.apply(tokenizer_lemma)
print()

for i in range(5):
    print(df_clean["name"].iloc[i])
    print("Texte original :", df_clean["text"].iloc[i])
    print("Texte nettoyé  :", df_nettoyer.iloc[i])
    print("Tokens stemmés :", df_tokenizer_stem.iloc[i])
    print("Tokens lemmatisés :", df_tokenizer_lemma.iloc[i])
    print()

# %%
corpus_nettoyer = {}
corpus_tokenizer_stem = {}
corpus_tokenizer_lemma = {}

# Nettoyage : corpus (brut) vers corpus_nettoyer
for Name in corpus:
    texte = corpus[Name]
    corpus_nettoyer[Name] = nettoyer_texte(texte)
    texte_nettoyer  = corpus_nettoyer[Name]
    
# Tokenisation : corpus_nettoyer -> stem + lemma
for Name in corpus_nettoyer:
    texte = corpus_nettoyer[Name]
    corpus_tokenizer_stem[Name] = tokenizer_stem(texte)
    corpus_tokenizer_lemma[Name] = tokenizer_lemma(texte)
    tokens_stem  = corpus_tokenizer_stem[Name]
    tokens_lemma = corpus_tokenizer_lemma[Name]
    print(Name)
    print("Texte original :", corpus[Name])
    print("Texte nettoyé  :", corpus_nettoyer[Name])
    print("Tokens stemmés :", tokens_stem)
    print("Tokens lemmatisés :", tokens_lemma)
    print()

# %% [markdown]
# Matrice terme-document

# %%
# Counter permet de compter les occurrences des éléments dans une liste
from collections import Counter
# Pour manipuler des tableaux de données
import pandas as pd

# step 1 : Prends chaque liste de tokens de chaque document, puis prends chaque token dans cette liste, 
# et mets tous ces tokens dans un set = pas de doublons.
vocabulary = set()
for tokens_stem in corpus_tokenizer_stem.values():
    for token in tokens_stem:
        vocabulary.add(token)
print(vocabulary)
print()

# Step 2: compte le nombre d'occurrences de chaque token dans chaque document/page
token_frequencies = {}
for Name, tokens_stem in corpus_tokenizer_stem.items():
    token_frequencies[Name] = Counter(tokens_stem)
print(token_frequencies)
print()

data = {}
for token in vocabulary:
    data[token] = []
    for document in corpus_tokenizer_stem:
        nombre = token_frequencies[document].get(token, 0)
        data[token].append(nombre)
print(data)
print()

td_matrix = pd.DataFrame(data, index=corpus_tokenizer_stem.keys())
display(td_matrix.head())
nb_doc = len(td_matrix)
print("Nombre de documents :", nb_doc)

# %% [markdown]
# Matrice terme-document filtrée

# %%
# arrondie
seuil_bas = int(nb_doc*0.1)+1
seuil_haut = int(nb_doc*0.9)
print("Nombre de documents :", nb_doc)
print("Seuil bas 10% des documents :", seuil_bas)
print("Seuil haut 90% des documents :", seuil_haut)

# Step 4: Enlever les mots qui apparaissent dans moins de 2 documents ()
present = td_matrix > 0
page_frequency = present.sum(axis=0)
filtrage_td_matrix = td_matrix.loc[:, page_frequency >= seuil_bas]

# Step 4: enlever les mots qui apparaissent dans tous les documents
present = filtrage_td_matrix > 0
page_frequency = present.sum(axis=0)
filtrage_td_matrix = filtrage_td_matrix.loc[:, page_frequency < nb_doc]

filtrage_vocabulary = filtrage_td_matrix.columns.tolist()

corpus_tokenizer_stem_filtre = {}
for nom_doc, tokens_stem in corpus_tokenizer_stem.items():
    corpus_tokenizer_stem_filtre[nom_doc] = [token for token in tokens_stem if token in filtrage_vocabulary]

token_filtrage_frequencies = {}
for Name, tokens_filtrees in corpus_tokenizer_stem_filtre.items():
    token_filtrage_frequencies[Name] = Counter(tokens_filtrees)
print(token_filtrage_frequencies)
print()

print(filtrage_td_matrix.head())
print(filtrage_vocabulary)
print()

# Print le filtrage de la term-document matrix
display(filtrage_td_matrix.head())

# %% [markdown]
# Matrice TF-IDF

# %%
import numpy as np

row_sums = filtrage_td_matrix.sum(axis=1)  # Total tokens par page/document
tf = filtrage_td_matrix.div(row_sums, axis=0)
df = (filtrage_td_matrix > 0).sum(axis=0)  
N = filtrage_td_matrix.shape[0]  
idf = np.log((N) / (df))
tf_idf = tf.mul(idf, axis=1)
display(tf_idf.head())

# %% [markdown]
# Matrice de similarité cosinus

# %%
import matplotlib.pyplot as plt
from sklearn.metrics.pairwise import cosine_similarity

# matrice de similarité cosinus
similarity_matrix_tfidf = cosine_similarity(tf_idf)

# convertir en DataFrame pour une meilleure lisibilité (peut etre suprimée)
similarity_df_tfidf = pd.DataFrame(similarity_matrix_tfidf, index=tf_idf.index, columns=tf_idf.index)

# affiche le DataFrame de similarité
#display(similarity_df_tfidf)

def plot_similarity_matrix(similarity_df_tfidf):
    # Affiche la matrice de similarité
    plt.figure(figsize=(25, 25))
    plt.imshow(similarity_df_tfidf, aspect="auto")
    plt.colorbar(label='Cosine Similarity')
    plt.title('Page internet (Similarity Matrix)')
    plt.xticks(ticks=range(len(similarity_df_tfidf.columns)), labels=similarity_df_tfidf.columns, rotation=90)
    plt.yticks(ticks=range(len(similarity_df_tfidf.index)), labels=similarity_df_tfidf.index)
    plt.xlabel('Page internet')
    plt.ylabel('Page internet')
    plt.show()

    # optionnellement, annoter les cellules avec les valeurs de similarité
    for i in range(len(similarity_df_tfidf)):
        for j in range(len(similarity_df_tfidf)):
            plt.text(j, i, f"{similarity_df_tfidf.iloc[i, j]:.3f}", ha='center', va='center', color='white')
    plt.tight_layout()

display(similarity_df_tfidf.head())

plot_similarity_matrix(similarity_df_tfidf)

names = similarity_df_tfidf.index.tolist()
print(names)

# %% [markdown]
# Classement de la similarité cosinus

# %%
# top paires hors diagonale
liste_similarites = []
nb_doc = similarity_matrix_tfidf.shape[0]
for i in range(nb_doc):
    for j in range(i+1, nb_doc):
        score = similarity_matrix_tfidf[i, j]
        doc_a = names[i]
        doc_b = names[j]
        liste_similarites.append((score, doc_a, doc_b))

liste_similarites.sort(reverse=True, key=lambda x: x[0])

print("Top 10 similarités (cosinus) :")
for score, doc_a, doc_b in liste_similarites[:10]:
    print(f"{score:.3f}  {doc_a} <-> {doc_b}")

# %% [markdown]
# Analyse descriptive

# %%
from wordcloud import WordCloud
from itertools import combinations

# TOP 20 TF-IDF MOYEN
tfidf_moyen = tf_idf.mean(axis=0).sort_values(ascending=False)

print("Top 20 termes (TF-IDF moyen) :")
for mot, score in tfidf_moyen.head(20).items():
    print(mot, round(score, 4))

# FREQUENCE GLOBALE (sur la matrice filtrée)
frequence_globale = {}  # dictionnaire : mot -> total

for mot in filtrage_td_matrix.columns:                 # chaque mot (colonne)
    total = filtrage_td_matrix[mot].sum()              # somme sur tous les docs
    frequence_globale[mot] = int(total)                # on garde un entier

# Afficher les 20 mots les plus fréquents
freq_triee = sorted(frequence_globale.items(), key=lambda x: x[1], reverse=True)

print("\nTop 20 mots les plus fréquents :")
for mot, nb in freq_triee[:20]:
    print(mot, nb)

# WORDCLOUD (taille = fréquence)
nuage = WordCloud(width=1200, height=600, background_color="white")
nuage = nuage.generate_from_frequencies(frequence_globale)

plt.figure(figsize=(12, 6))
plt.imshow(nuage, interpolation="bilinear")
plt.axis("off")
plt.title("WordCloud (fréquence globale)")
plt.show()

# COOCCURRENCES (par document) par exemple "mot A et mot B apparaissent ensemble dans combien de documents ?"
cooccurrences = Counter()  # (motA, motB) -> nb_documents

for nom_doc, tokens in corpus_tokenizer_stem_filtre.items():
    mots_uniques = sorted(set(tokens))  # une seule fois par doc (pas de biais si répété)
    
    for paire in combinations(mots_uniques, 2):  # toutes les paires possibles
        cooccurrences[paire] += 1

print("\nTop 20 cooccurrences (document-level) :")
for (motA, motB), nb_docs in cooccurrences.most_common(20):
    print(motA, "-", motB, ":", nb_docs)

# %% [markdown]
# Analyse sémantique

# %%
from sentence_transformers import SentenceTransformer

# Noms + textes (texte brut)
doc_names = list(corpus_nettoyer.keys())
documents = list(corpus_nettoyer.values())

# Modèle SBERT
model = SentenceTransformer("all-MiniLM-L6-v2")

# Embeddings (vecteurs sémantiques)
embeddings = model.encode(documents, normalize_embeddings=True)

# Similarité cosinus
similarity_matrix_bert = cosine_similarity(embeddings)

# DataFrame lisible
similarity_df_bert = pd.DataFrame(
    similarity_matrix_bert,
    index=doc_names,
    columns=doc_names
)

display(similarity_df_bert.head())
plot_similarity_matrix(similarity_df_bert)

# %% [markdown]
# Clustering

# %%
from sklearn.cluster import KMeans

# Nombres de clusters
k = 2

# Clustering sur TF-IDF
kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
labels = kmeans.fit_predict(tf_idf)

# Mettre le résultat dans un tableau lisible
df_clusters = pd.DataFrame({
    "document": tf_idf.index,
    "cluster": labels
})

# 4) Voir les documents par groupe
print(df_clusters.sort_values("cluster"))

# %%
from sklearn.decomposition import PCA

# Réduire tf_idf en 2 dimensions
pca = PCA(n_components=2, random_state=42)
points_2d = pca.fit_transform(tf_idf.values)

# plot
plt.figure(figsize=(10, 7))
plt.scatter(points_2d[:, 0], points_2d[:, 1], c=labels)
plt.title("Clustering des documents (TF-IDF + PCA)")
plt.xlabel("Axe 1 (PCA)")
plt.ylabel("Axe 2 (PCA)")
plt.show()

for c in sorted(df_clusters["cluster"].unique()):
    print()
    print("CLUSTER", c)
    print()
    docs = df_clusters[df_clusters["cluster"] == c]["document"].tolist()
    for d in docs:
        print("-", d)

# %% [markdown]
# Link Analysis

# %%
import networkx as nx
from bs4 import BeautifulSoup
from urllib.parse import urljoin, urldefrag

# Noeuds correspond à toutes les URLs qu'on a gardées après la data collection, on défintit les noeuds du graphe
urls = df_excel_out["url"].dropna().astype(str).str.strip().tolist()
urls = [u for u in urls if u != ""]
urls_set = set(urls)  # enlève doublons

print("Nb noeuds (URLs) :", len(urls_set))

# Trouver les liens sortants d'une page et garder seulement ceux dans notre liste)
def liens_vers_notre_liste(html, base_url):
    soup = BeautifulSoup(html, "html.parser")
    liens = set()

    for a in soup.find_all("a", href=True):
        href = a["href"].strip()

        # on filtre les liens qui ne sont pas des liens web : ancre interne à la meme page + mail + tel + javascript
        if href.startswith("#") or href.startswith("mailto:") or href.startswith("tel:") or href.startswith("javascript:"):
            continue

        lien = urljoin(base_url, href)      # reconstruit le lien absolu
        lien = urldefrag(lien)[0]           # enlève le #...
        lien = lien.strip()

        # on garde uniquement si c'est une URL de notre liste
        if lien in urls_set:
            liens.add(lien)

    return list(liens)

# Construire les arêtes (liens entre pages)
edges = []

for url in urls_set:
    status_code, html = read_html_url(url) # lire le contenu de la page
    if status_code != 200 or html == "" or html is None: # pas de contenu, on ignore
        continue

    targets = liens_vers_notre_liste(html, url) # trouver les liens vers notre liste
    for t in targets:
        edges.append((url, t))

print("Nb liens internes trouvés :", len(edges))

# Création du graphe orienté
G = nx.DiGraph()
G.add_nodes_from(urls_set)   # même sans liens
G.add_edges_from(edges)

print("Noeuds :", G.number_of_nodes(), "| liens :", G.number_of_edges())

# %%
import pandas as pd
import networkx as nx

# Degree centrality (ici: in/out degree)
in_deg = dict(G.in_degree())
out_deg = dict(G.out_degree())

# Betweenness centrality
bet = nx.betweenness_centrality(G, normalized=True)

# PageRank
pr = nx.pagerank(G)

# Shortest path (sur la plus grande composante)
# Sinon, si le graphe pas connecté => distances infinies
components = list(nx.weakly_connected_components(G)) # toutes les composantes connexes
biggest = max(components, key=len) if len(components) > 0 else set() # composante la plus grande
G_big = G.subgraph(biggest).to_undirected() # graphe non orienté de la plus grande composante

if G_big.number_of_nodes() >= 2: # au moins 2 noeuds connectés
    avg_sp = nx.average_shortest_path_length(G_big) # distance moyenne
    diam = nx.diameter(G_big) # diamètre du graphe
    print("Shortest path (plus grande composante) :")
    print("- distance moyenne :", round(avg_sp, 2))
    print("- diamètre :", diam)
else:
    print("Shortest path : impossible (pas assez de noeuds connectés).")

# Résultat dans un tableau
df_link = pd.DataFrame({
    "url": list(G.nodes()),
    "in_degree": [in_deg[u] for u in G.nodes()],
    "out_degree": [out_deg[u] for u in G.nodes()],
    "betweenness": [bet[u] for u in G.nodes()],
    "pagerank": [pr[u] for u in G.nodes()],
})

df_link["degree_total"] = df_link["in_degree"] + df_link["out_degree"]

print("\nTop 10 PageRank :")
display(df_link.sort_values("pagerank", ascending=False).head(10))

print("\nTop 10 Betweenness :")
display(df_link.sort_values("betweenness", ascending=False).head(10))

print("\nTop 10 In-degree :")
display(df_link.sort_values("in_degree", ascending=False).head(10))

# Export du graphe Gephi
nx.set_node_attributes(G, in_deg, "in_degree")
nx.set_node_attributes(G, out_deg, "out_degree")
nx.set_node_attributes(G, bet, "betweenness")
nx.set_node_attributes(G, pr, "pagerank")

nx.write_gexf(G, "web_graph.gexf")
